# %% [markdown]
# ![](img/shark.png)

# %% [markdown]
# # Global Shark Attack
#
# Fecha de entrega: _23:59 05/04/2021_

# %% [markdown]
# ### ¿En qué consiste este mini-proyecto?
#
# El objetivo de este mini-proyecto es que os enfrentéis a realizar un Exploratory Data Analysis por primera vez, antes del proyecto EDA.
#
# Durante este mini-proyecto deberás poner en práctica todo lo aprendido durante las últimas semanas. Tanto cómo te haga falta y solo si te hace falta. Esta vez serás tú el qué tome la decisión de qué tratamientos o limpiezas y visualizaciones serán mejor para tratar tus datos.
#
# Mínimo deberás importar las siguientes librerías, aunque te animo a explorar otras librerías nuevas.
#
# ```python
# import pandas as pd
# import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns
# ```
#
# Todo esto con el fin de poder verificar nuestra hipótesis. Sigue leyendo para más información.

# %% [markdown]
# ### Dataset

# %% [markdown]
# El dataset que utilizaremos para este mini-proyecto contiene datos sobre los ataques de tiburones en el mundo: localicación, fechas, tipología, especie causante, información sobre las víctimas, etc..
#
# Registrado por http://www.sharkattackfile.net/index.htm.
#
# Te lo podrás descargar en este enlace: https://www.kaggle.com/teajay/global-shark-attacks

# %% [markdown]
# ### Hipótesis
# Elige una o varias de estas hipótesis para desarrollar tu mini proyecto.
#
# Siéntete libre de establecer nuevas hipótesis que puedas validar o rechazar con tu análisis.

# %% [markdown]
# - El número de supervivientes ha aumentado con el paso de los años
# - Todos los ataques producidos en la India, ocurren a primera hora de la mañana
# - La mayoría de los ataques en los últimos 200 años tuvieron lugar en USA, Australia y Sudáfrica.
# - Las actividades con más riesgo de sufrir un ataque de tiburon son pescar y nadar.
# - La mayoría de los ataques de tiburón fueron fatales.
# - Los tiburones tienen especial predilección por los surferos.
# - Reunion Island es el lugar del mundo donde ocurren más ataques de tiburón en terminos relativos.
# - En Sudáfrica hay más ataques letales a mujeres que en Australia.

# %% [markdown]
# ### Github*
# *_Este punto es opcional pero MUY recomendable, ya que en el Proyecto de EDA será obligatorio_
#
# Crea un repositorio nuevo para guardar los archivos que necesites.
#
# Sigue la siguiente estructuras de carpetas:
#
#     - src -> aquí encontrarás el código, en este caso los notebooks que uses
#     - input -> aquí guardarás el dataset que utilices
#     - output -> aquí guardarás gráficas o datasets limpios, si los tuvieras

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
# %matplotlib inline

# %%
attack = pd.read_csv('attacks.csv',encoding='latin-1')

# %%
attack.shape
# Out:
# (25723, 24)

# %%
attack.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
#        'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
#        'Unnamed: 23'],
#       dtype='object')

# %%
attack.drop(['Unnamed: 22','Unnamed: 23'], axis = 1 , inplace = True)

# %%
attack.drop(['Case Number.2'], axis = 1 , inplace = True)

# %%
attack.drop(['href formula'], axis = 1 , inplace = True)

# %%
attack.drop(['Case Number.1'], axis = 1 , inplace = True)

# %%
attack.dropna(axis = 0, how = "all" ,inplace = True )

# %%
#attack.dropna(axis = 0, how = "any" ,inplace = True)

# %%
attack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8703 entries, 0 to 25722
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
#  14  Species                 3464 non-null   object
#  15  Investigator or Source  6285 non-null   object
#  16  pdf                     6302 non-null   object
#  17  href                    6302 non-null   object
#  18  original order          6309 non-null   float64
# dtypes: float64(2), object(17)
# memory usage: 1.3+ MB

# %%
attack.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
attack.isnull().sum()
# Out:
# Case Number                  1
# Date                      2401
# Year                      2403
# Type                      2405
# Country                   2451
# Area                      2856
# Location                  2941
# Activity                  2945
# Name                      2611
# Sex                       2966
# Age                       5232
# Injury                    2429
# Fatal (Y/N)               2940
# Time                      5755
# Species                   5239
# Investigator or Source    2418
# pdf                       2401
# href                      2401
# original order            2394
# dtype: int64

# %%
attack.set_index('original order',inplace=True)

# %%
attack.columns
# Out:
# Index(['Case Number', 'Date', 'Year', 'Type', 'Country', 'Area', 'Location',
#        'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time',
#        'Species ', 'Investigator or Source', 'pdf', 'href', 'original order'],
#       dtype='object')

# %%
attack= attack.rename(columns={'Sex ' : 'Sex' , 'Fatal (Y/N)':'Survived (Y/N)'})

# %%
attack['Sobrevivio'] = attack['Survived (Y/N)'].map({'Y' : 'Yes', 'N' : 'No'})

# %%
attack.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex  Age  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe   F   57
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely    F   11
# 2                    Habush, Oahu      Surfing      John Denges   M   48
# 3              Arrawarra Headland      Surfing             male   M  NaN
# 4                        La Ticla  Free diving   Gustavo Ramos    M  NaN
#
#                                               Injury Survived (Y/N)  \
# 0  No injury to occupant, outrigger canoe and pad...              N
# 1                         Minor injury to left thigh              N
# 2       Injury to left lower leg from surfboard skeg              N
# 3                          Minor injury to lower leg              N
# 4  Lacerations to leg & hand shark PROVOKED INCIDENT              N
#
#             Time         Species           Investigator or Source  \
# 0          18h00      White shark                R. Collier, GSAF
# 1  14h00  -15h00              NaN  K.McMurray, TrackingSharks.com
# 2          07h45              NaN  K.McMurray, TrackingSharks.com
# 3            NaN        2 m shark                  B. Myatt, GSAF
# 4            NaN  Tiger shark, 3m                       A .Kipper
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# 1    2018.06.18-McNeely.pdf
# 2     2018.06.09-Denges.pdf
# 3  2018.06.08-Arrawarra.pdf
# 4      2018.06.04-Ramos.pdf
#
#                                                 href  original order  \
# 0  http://sharkattackfile.net/spreadsheets/pdf_di...          6303.0
# 1  http://sharkattackfile.net/spreadsheets/pdf_di...          6302.0
# 2  http://sharkattackfile.net/spreadsheets/pdf_di...          6301.0
# 3  http://sharkattackfile.net/spreadsheets/pdf_di...          6300.0
# 4  http://sharkattackfile.net/spreadsheets/pdf_di...          6299.0
#
#   Sobrevivio
# 0         No
# 1         No
# 2         No
# 3         No
# 4         No

# %% [markdown]
# #  1 .) El número de supervivientes ha aumentado con el paso de los años ?

# %%
example = attack.groupby('Year')[['Sobrevivio']].count().sort_values( by = 'Year' , ascending = False).head(20)
example
# Out:
#         Sobrevivio
# Year
# 2018.0          52
# 2017.0         123
# 2016.0         118
# 2015.0         130
# 2014.0         118
# 2013.0         114
# 2012.0         107
# 2011.0         118
# 2010.0          97
# 2009.0         110
# 2008.0         110
# 2007.0         101
# 2006.0          93
# 2005.0          91
# 2004.0          83
# 2003.0          86
# 2002.0          84
# 2001.0          87
# 2000.0          91
# 1999.0          63

# %%
people_survived = attack[attack['Sobrevivio']== 'Yes']
people_survived.head()
# Out:
#                  Case Number                  Date    Year          Type  \
# original order
# 6297.0          2018.06.03.a           03-Jun-2018  2018.0    Unprovoked
# 6245.0          2017.11.30.a           30-Nov-2017  2017.0    Unprovoked
# 6244.0          2017.11.25.R  Reported 25-Nov-2017  2017.0  Sea Disaster
# 6239.0            2017.11.04           04-Nov-2017  2017.0    Unprovoked
# 6212.0          2017.09.03.b           03-Sep-2017  2017.0    Unprovoked
#
#                      Country                   Area               Location  \
# original order
# 6297.0                BRAZIL             Pernambuco  Piedade Beach, Recife
# 6245.0            COSTA RICA           Cocos Island              Manuelita
# 6244.0                 LIBYA                    NaN         Gars Garabulli
# 6239.0                  CUBA       Holquin Province     Guardalavaca Beach
# 6212.0          SOUTH AFRICA  Western Cape Province            Dyer Island
#
#                                   Activity                     Name  Sex  Age  \
# original order
# 6297.0                            Swimming   Jose Ernesto da Silva     M   18
# 6245.0                        Scuba diving          Rohina Bhandari    F   49
# 6244.0                    2 boats capsized              31 migrants  NaN  NaN
# 6239.0                       Night bathing  Jesús Cabrera González     M   22
# 6212.0          Swimming, poaching abalone          Sivuyile Xelela    M  NaN
#
#                Injury Survived (Y/N)            Time  \
# original order
# 6297.0          FATAL              Y  Late afternoon
# 6245.0          FATAL              Y             NaN
# 6244.0          FATAL              Y             NaN
# 6239.0          FATAL              Y           23h30
# 6212.0          FATAL              Y         Morning
#
#                                                          Species   \
# original order
# 6297.0                                                Tiger shark
# 6245.0                                        Tiger shark, female
# 6244.0          Some drowned but other may have been killed by...
# 6239.0                                                Tiger shark
# 6212.0                                                        NaN
#
#                         Investigator or Source                        pdf  \
# original order
# 6297.0          Diario de Pernambuco, 6/4/2018   2018.06.03.a-daSilva.pdf
# 6245.0                                R. Arauz  2017.11.30.a-Bhandari.pdf
# 6244.0                   TG Com 24, 11/25/2017     2017.11.25.R-Libya.pdf
# 6239.0                      TrackingSharks.com        2017.11.04-Cuba.pdf
# 6212.0                  All Africa, 10/11/2017    2017.09.03.b-Xelela.pdf
#
#                                                              href Sobrevivio
# original order
# 6297.0          http://sharkattackfile.net/spreadsheets/pdf_di...        Yes
# 6245.0          http://sharkattackfile.net/spreadsheets/pdf_di...        Yes
# 6244.0          http://sharkattackfile.net/spreadsheets/pdf_di...        Yes
# 6239.0          http://sharkattackfile.net/spreadsheets/pdf_di...        Yes
# 6212.0          http://sharkattackfile.net/spreadsheets/pdf_di...        Yes

# %%
example.plot(kind = 'bar' ,color = 'cyan')
plt.title('Numero de sobriviviente por años', color = 'b',fontsize= 30 )
# Out:
# Text(0.5, 1.0, 'Numero de sobriviviente por años')

# %%
sns.catplot('Year', 'Sobrevivio', data = attack , kind = 'point' , color = 'g')
# Out:
# C:\Users\rafae\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sns.kdeplot(data=example,x = 'Year' , shade = True , color = 'g' ,)
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Density'>

# %%
plt.figure(figsize=(10,7))
sns.kdeplot(data=attack,x = 'Year' ,hue = 'Sobrevivio', shade = True  ,)
plt.xlim(1800,2200)
# Out:
# (1800.0, 2200.0)

# %% [markdown]
# # 2.) Todos los ataques producidos en la India, ocurren a primera hora de la mañana

# %%
india['Time'] = india['Time'].apply(lambda x: str(x).replace('Evening','19:00'))
india['Time'] = india['Time'].apply(lambda x: str(x).replace('Before ',''))
# Out:
# <ipython-input-19-91da414235a6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india['Time'] = india['Time'].apply(lambda x: str(x).replace('Evening','19:00'))
# <ipython-input-19-91da414235a6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india['Time'] = india['Time'].apply(lambda x: str(x).replace('Before ',''))

# %%
india['Time'] = india['Time'].apply(lambda x: str(x).replace('Evening','17:00'))
# Out:
# <ipython-input-20-6c7bc6d9545f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india['Time'] = india['Time'].apply(lambda x: str(x).replace('Evening','17:00'))

# %%
india['Time'] = india['Time'].apply(lambda x: str(x).replace('17:00-',''))
# Out:
# <ipython-input-24-d116fc458c1c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india['Time'] = india['Time'].apply(lambda x: str(x).replace('17:00-',''))

# %%
india['Time'] = india['Time'].apply(lambda x: str(x).replace('h',':'))
# Out:
# <ipython-input-22-1c9be73e459c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   india['Time'] = india['Time'].apply(lambda x: str(x).replace('h',':'))

# %%
india.Time.values
# Out:
# array(['nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan',
#        'nan', '13:00', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan', '11:00',
#        'nan', '12:00', '10:00', 'nan', 'nan', 'nan', 'nan', 'nan', 'nan',
#        'nan', '10:30', 'nan', '19:00', '18:00', '19:00', 'nan', 'nan',
#        'nan', 'nan', 'nan', 'nan', 'nan'], dtype=object)

# %%
#india.Time.infer_objects() # converti la columna en objeto para poder remplazarla

#india[['Time']] = india[['Time']].astype(float)

# %%
sns.catplot(x = 'Time', kind="count", data=india , hue = 'Sobrevivio',palette = 'winter')

# %%
india = attack[attack['Country']== 'INDIA']

# %%
india['Time'] = india['Time'].replace('nan', np.nan)

# %%
india['Time'].dropna(inplace=True)

# %% [markdown]
# # 3.) La mayoría de los ataques en los últimos 200 años tuvieron lugar en USA, Australia y Sudáfrica?

# %%
attack = attack.sort_values('Country')

# %%
mayoria = attack[(attack['Country'] == 'USA') | (attack['Country'] == 'AUSTRALIA') | (attack['Country'] == 'SOUTHAFRICA')]

# %%
# Out:
#        Case Number                  Date    Year        Type    Country  \
# 5441    1907.12.21           21-Dec-1907  1907.0  Unprovoked  AUSTRALIA
# 1066    2009.12.13           13-Dec-2009  2009.0  Unprovoked  AUSTRALIA
# 1067    2009.12.12           12-Dec-2009  2009.0     Boating  AUSTRALIA
# 5442  1907.10.18.R  Reported 18-Oct-1907  1907.0  Unprovoked  AUSTRALIA
# 4572  1947.07.24.R  Reported 24-Jul-1947  1947.0  Unprovoked  AUSTRALIA
# ...            ...                   ...     ...         ...        ...
# 2240  1997.08.02.a           02-Aug-1997  1997.0  Unprovoked        USA
# 2193    1998.04.21           21-Apr-1998  1998.0  Unprovoked        USA
# 2190  1998.05.16.b           16-May-1998  1998.0  Unprovoked        USA
# 2037    2000.07.09           09-Jul-2000  2000.0  Unprovoked        USA
# 2237    1997.08.05           05-Aug-1997  1997.0  Unprovoked        USA
#
#                     Area                                         Location  \
# 5441     New South Wales  Middle Harbour, Sugarloaf Bay, Sydney (Estuary)
# 1066     New South Wales                                      Coffee Head
# 1067     New South Wales                                 Hawks Nest Beach
# 5442       Torres Strait                             Near Thursday Island
# 4572  Northern Territory                                   Darwin Harbour
# ...                  ...                                              ...
# 2240             Florida                 New Smyrna Beach, Volusia County
# 2193              Oregon                                   Gleneden Beach
# 2190             Florida                   Walden Rocks, St. Lucie County
# 2037             Florida     Neptune Avenue, Ormond Beach, Volusia County
# 2237               Texas                            East Beach, Galveston
#
#                                 Activity  \
# 5441                             Bathing
# 1066                             Surfing
# 1067                              Rowing
# 5442                             Bathing
# 4572                              Diving
# ...                                  ...
# 2240                    Wading / Surfing
# 2193  Surfing (lying prone on his board)
# 2190                  Swimming / surfing
# 2037                           Swimming
# 2237                              Wading
#
#                                       Name  Sex  Age  \
# 5441                           Henry Jones    M  NaN
# 1066                          Nigel Hughes    M   39
# 1067  Surf boat with 5 lifesavers on board  NaN  NaN
# 5442           male from the lugger Teazer    M  NaN
# 4572                          A.S. Festing    M  NaN
# ...                                    ...  ...  ...
# 2240                         Matthew Perny    M   19
# 2193                            John Forse    M   50
# 2190                           Roger Moore    M   24
# 2037                          Anthony Zent    M   41
# 2237                                female    F   10
#
#                                               Injury Survived (Y/N)    Time  \
# 5441                                           FATAL              Y     NaN
# 1066                           Laceration to big toe              N   07h00
# 1067  No injury to occupants; shark bit steering oar              N   07h30
# 5442                                           FATAL              Y     NaN
# 4572                                     Suit ripped              N     NaN
# ...                                              ...            ...     ...
# 2240                         Top of left foot bitten              N   09h15
# 2193                              Right thigh bitten              N  09h30
# 2190                      Left arm & wrist lacerated              N   15h00
# 2037                           Knee & calf lacerated              N   18h00
# 2237                               Wrist & am bitten              N     NaN
#
#                         Species   \
# 5441                  Bull shark
# 1066                         NaN
# 1067                 White shark
# 5442                         NaN
# 4572  Most likely, a small shark
# ...                          ...
# 2240            "juvenile shark"
# 2193     5 m [16.5'] white shark
# 2190                         NaN
# 2037                         NaN
# 2237                   1 m shark
#
#                                  Investigator or Source  \
# 5441    R.D. Weeks, GSAF; Otago Daily Times, 12/24/1907
# 1066                          Northern Star, 12/14/2009
# 1067                             Herald Sun, 12/13/2009
# 5442                       The Queenslander, 10/26/1907
# 4572                          Canberra Times, 7/25/1947
# ...                                                 ...
# 2240  S. Petersohn, GSAF; D. Catron, Orlando Sentine...
# 2193                             R. Collier, pp.161-163
# 2190                    The Stuart (FL) News, 5/17/1998
# 2037  S. Petersohn, GSAF: H. Frederick, Daytona Beac...
# 2237          Austin American Statesman, 8/7/1997, p.C8
#
#                                pdf  \
# 5441          1907.12.21-Jones.pdf
# 1066         2009.12.13-Hughes.pdf
# 1067      2009.12.12-Ross-boat.pdf
# 5442  1907.10.18.R-male-Teazer.pdf
# 4572      1947.07.24.R-Festing.pdf
# ...                            ...
# 2240        1997.08.02.a-Perny.pdf
# 2193  1998.04.21-Forse_Collier.pdf
# 2190        1998.05.16.b-Moore.pdf
# 2037           2000.07.09-Zent.pdf
# 2237      1997.08.05-Galveston.pdf
#
#                                                    href  original order  \
# 5441  http://sharkattackfile.net/spreadsheets/pdf_di...           862.0
# 1066  http://sharkattackfile.net/spreadsheets/pdf_di...          5237.0
# 1067  http://sharkattackfile.net/spreadsheets/pdf_di...          5236.0
# 5442  http://sharkattackfile.net/spreadsheets/pdf_di...           861.0
# 4572  http://sharkattackfile.net/spreadsheets/pdf_di...          1731.0
# ...                                                 ...             ...
# 2240  http://sharkattackfile.net/spreadsheets/pdf_di...          4063.0
# 2193  http://sharkattackfile.net/spreadsheets/pdf_di...          4110.0
# 2190  http://sharkattackfile.net/spreadsheets/pdf_di...          4113.0
# 2037  http://sharkattackfile.net/spreadsheets/pdf_di...          4266.0
# 2237  http://sharkattackfile.net/spreadsheets/pdf_di...          4066.0
#
#      Sobrevivio
# 5441        Yes
# 1066         No
# 1067         No
# 5442        Yes
# 4572         No
# ...         ...
# 2240         No
# 2193         No
# 2190         No
# 2037         No
# 2237         No
#
# [3567 rows x 20 columns]

# %%
plt.figure(figsize=(10,7))
sns.kdeplot('Year', data = mayoria , hue = 'Country', shade = True )
plt.xlim(1700, 2200)
# Out:
# (1700.0, 2200.0)

# %%
plt.figure(figsize=(10,7))
sns.catplot('Country', data = mayoria ,kind = 'count', palette = 'summer' , hue = 'Sobrevivio')
plt.title('Mayoria de Ataques',fontsize= 30)
# Out:
# C:\Users\rafae\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'Mayoria de Ataques')

# %%
plt.figure(figsize=(10,7))
sns.boxplot(data= mayoria , y = 'Year', x = 'Country').set_title('Mayoria de Ataques',fontsize= 45)
plt.ylim(1700,2050)
# Out:
# (1700.0, 2050.0)

# %%
attack['Country'].unique()
attack[attack['Country'].str.contains('AFRICA')]
attack[attack['Country']== 'SOUTHAFRICA']
# Out:
#        Case Number         Date    Year        Type      Country  \
# 4662    1943.12.12  12-Dec-1943  1943.0  Unprovoked  SOUTHAFRICA
# 3451    1968.11.06  06-Nov-1968  1968.0        Boat  SOUTHAFRICA
# 4625    1945.03.06  06-Mar-1945  1945.0  Unprovoked  SOUTHAFRICA
# 4652    1944.03.14  14-Mar-1944  1944.0  Unprovoked  SOUTHAFRICA
# 5390    1911.05.01  01-May-1911  1911.0  Unprovoked  SOUTHAFRICA
# ...            ...          ...     ...         ...          ...
# 3276  1974.02.00.b     Feb-1974  1974.0        Boat  SOUTHAFRICA
# 1606    2005.03.10  10-Mar-2005  2005.0     Invalid  SOUTHAFRICA
# 3135  1977.12.19.a  19-Dec-1977  1977.0  Unprovoked  SOUTHAFRICA
# 3243    1975.02.01  01-Feb-1975  1975.0    Provoked  SOUTHAFRICA
# 15      2018.05.12  12-May-2018  2018.0  Unprovoked  SOUTHAFRICA
#
#                        Area                    Location              Activity  \
# 4662          KwaZulu-Natal   Inyoni Rocks, Amazimtoti         Treading water
# 3451          KwaZulu-Natal                    Ramsgate               Fishing
# 4625          KwaZulu-Natal                  Scottburgh               Walking
# 4652          KwaZulu-Natal  Country Club Beach, Durban        Treading water
# 5390  Western Cape Province                Victoria Bay              Swimming
# ...                     ...                         ...                   ...
# 3276  Western Cape Province                    Macassar  Fishing for red fish
# 1606          KwaZulu-Natal                    Isipingo                   NaN
# 3135  Eastern Cape Province                Qolera River               Surfing
# 3243  Western Cape Province         Beespens, False Bay               Fishing
# 15    Eastern Cape Province   Nahoon Beach, East London               Surfing
#
#                                                    Name  Sex  Age  \
# 4662                            James Crawford Matthews    M   17
# 3451  fishing boat, occupants: Simon Hlope & 4 other...    M   22
# 4625                                     David Drummond    M   37
# 4652                                   Richard D. Field    M   16
# 5390                                      James Jantjes    M  NaN
# ...                                                 ...  ...  ...
# 3276                  skiboat, occupant: Danie Schoeman  NaN  NaN
# 1606                               Anthony Arnachallan     M   51
# 3135                                         Kim Pearce    M   18
# 3243                                     Gerhard Visser    M   12
# 15                                                 male    M  NaN
#
#                                                  Injury Survived (Y/N)   Time  \
# 4662        FATAL, abdomen, buttock & thigh lacerated                Y  11h30
# 3451  Shark leapt into boat, landed on Hlope's back,...              N    NaN
# 4625  Right leg bitten knee to foot, surgically ampu...              N  16h30
# 4652                           Ankle severely lacerated              N  17h30
# 5390                                              FATAL              Y    NaN
# ...                                                 ...            ...    ...
# 3276  No injury to occupant, but  a shark chasing a ...              N    NaN
# 1606        Bites by 2.5 m tiger shark were post mortem            NaN    NaN
# 3135  Both legs bitten, 2 days later gangrene necess...              N  10h00
# 3243  Foot bitten by shark he was gaffing  PROVOKED ...              N    NaN
# 15                         Minor injury, marks on board              N  11h00
#
#                                 Species   \
# 4662                                 NaN
# 3451              90-kg "blackfin" shark
# 4625  Thought to involve a Zambesi shark
# 4652                                 NaN
# 5390                                 NaN
# ...                                  ...
# 3276                     5 m white shark
# 1606                             Invalid
# 3135              Tiger shark, 3 m [10']
# 3243        Copper shark, 50-kg [110-b]
# 15                                   NaN
#
#                                  Investigator or Source  \
# 4662  R. Kahn, M. Levine, GSAF; Natal Mercury 1/21/1944
# 3451                                    M. Levine, GSAF
# 4625                       D. Drummond, M. Levine, GSAF
# 4652                       R.D. Field, M. Levine, GSAF
# 5390  Cape Mercantile Advertiser, 5/2/1911, M. Levin...
# ...                                                 ...
# 3276                                   T. Wallett, p.37
# 1606                J. Govander, Nokia Sea Rescue, SAPA
# 3135  K. Pearce, M. Levine, GSAF;  W. Pople, B. Davi...
# 3243                                The Argus, 2/3/1975
# 15                    B.Jacob, Dispatch Live, 5/12/2018
#
#                              pdf  \
# 4662     1943.12.12-Matthews.pdf
# 3451        1968.11.06-Hlope.pdf
# 4625     1945.03.06-Drummond.pdf
# 4652        1944.03.14-Field.pdf
# 5390     1911.05.01-Jantjies.pdf
# ...                          ...
# 3276   1974.02.00.b-Schoeman.pdf
# 1606  2005.03.10-Arnachallan.pdf
# 3135     1977.12.19.a-Pearce.pdf
# 3243       1975.02.01-Visser.pdf
# 15     2018.05.12-EastLondon.pdf
#
#                                                    href  original order  \
# 4662  http://sharkattackfile.net/spreadsheets/pdf_di...          1641.0
# 3451  http://sharkattackfile.net/spreadsheets/pdf_di...          2852.0
# 4625  http://sharkattackfile.net/spreadsheets/pdf_di...          1678.0
# 4652  http://sharkattackfile.net/spreadsheets/pdf_di...          1651.0
# 5390  http://sharkattackfile.net/spreadsheets/pdf_di...           913.0
# ...                                                 ...             ...
# 3276  http://sharkattackfile.net/spreadsheets/pdf_di...          3027.0
# 1606  http://sharkattackfile.net/spreadsheets/pdf_di...          4697.0
# 3135  http://sharkattackfile.net/spreadsheets/pdf_di...          3168.0
# 3243  http://sharkattackfile.net/spreadsheets/pdf_di...          3060.0
# 15    http://sharkattackfile.net/spreadsheets/pdf_di...          6288.0
#
#      Sobrevivio
# 4662        Yes
# 3451         No
# 4625         No
# 4652         No
# 5390        Yes
# ...         ...
# 3276         No
# 1606        NaN
# 3135         No
# 3243         No
# 15           No
#
# [579 rows x 20 columns]

# %%
attack['Country'] = attack['Country'].apply(lambda x : str(x).upper())

# %%
attack['Country'] = attack['Country'].apply(lambda x: x.replace('?',''))
attack['Country'] = attack['Country'].apply(lambda x: x.replace(' ',''))

# %%
#attack['Time'] = attack['Time'].apply(lambda x: x.replace('',''))

# %%
#attack['Time'] = attack['Time'].apply(lambda x: x.replace('>',''))

# %% [markdown]
# # 4.) Las actividades con más riesgo de sufrir un ataque de tiburon son pescar y nadar.

# %%
attack[['Activity']]

# %% [markdown]
# # 5.) La mayoría de los ataques de tiburón fueron fatales?

# %%
fatal =attack[attack['Injury']== 'FATAL']
fatal
# Out:
#         Case Number                  Date    Year        Type         Country  \
# 6049   1846.09.30.R  Reported 30-Sep-1846  1846.0  Unprovoked          AFRICA
# 6058   1844.07.16.R          1844.07.16.R  1844.0  Unprovoked         ALGERIA
# 4316     1954.12.29           29-Dec-1954  1954.0  Unprovoked   AMERICANSAMOA
# 5959  1863.00.00.R4                  1863  1863.0  Unprovoked  ANDAMANISLANDS
# 325      2015.12.19           19-Dec-2015  2015.0  Unprovoked           ARUBA
# ...             ...                   ...     ...         ...             ...
# 6119     1811.03.01           01-Mar-1811  1811.0  Unprovoked             NAN
# 6133   1797.05.28.R  Reported May-28-1797  1797.0  Unprovoked             NAN
# 6137     1787.07.05           05-Jul-1787  1787.0  Unprovoked             NAN
# 6155     1742.12.17           17-Dec-1742  1742.0  Unprovoked             NAN
# 6175     0077.00.00              77  A.D.    77.0  Unprovoked             NAN
#
#                 Area                               Location  \
# 6049             NaN                                    NaN
# 6058             NaN                           Cape Matifou
# 4316  Tutuila Island  Near tuna cannery in Pago Pago Harbor
# 5959             NaN                                    NaN
# 325              NaN                          Boat capsized
# ...              ...                                    ...
# 6119             NaN                                    NaN
# 6133             NaN                                    NaN
# 6137       St Helena                          Landing Place
# 6155             NaN                           Carlisle Bay
# 6175      Ionian Sea                                    NaN
#
#                                                Activity  \
# 6049                                  Jumped into river
# 6058                                           Swimming
# 4316  Dived overboard & was swimming near stern of t...
# 5959                                     Fell overboard
# 325                                        Sea disaster
# ...                                                 ...
# 6119                                     Fell overboard
# 6133                                  Dropped overboard
# 6137                                           Swimming
# 6155                                           Swimming
# 6175                                      Sponge diving
#
#                                                Name  Sex  Age Injury  \
# 6049                                           male    M  NaN  FATAL
# 6058                                           male    M  NaN  FATAL
# 4316  Kosuo Mizokawa, Captain of a Japanese trawler    M   27  FATAL
# 5959                              a local fisherman    M  NaN  FATAL
# 325                           Adrian Esteban Rafael    M   58  FATAL
# ...                                             ...  ...  ...    ...
# 6119                                    John Walker    M  NaN  FATAL
# 6133                                          child  NaN  NaN  FATAL
# 6137                         Private Isaac Hicksled    M  NaN  FATAL
# 6155                             2 impressed seamen    M  NaN  FATAL
# 6175                                          males    M  NaN  FATAL
#
#      Survived (Y/N)   Time Species   \
# 6049              Y    NaN      NaN
# 6058              Y    NaN      NaN
# 4316              Y    NaN      NaN
# 5959              Y  10h00      NaN
# 325               Y    NaN      NaN
# ...             ...    ...      ...
# 6119              Y    NaN      NaN
# 6133              Y    NaN      NaN
# 6137              Y    NaN      NaN
# 6155              Y    NaN      NaN
# 6175              Y    NaN      NaN
#
#                                  Investigator or Source  \
# 6049                        Hartford Courant, 9/30/1846
# 6058                                     C. Moore, GSAF
# 4316                Townsville Daily Bulletin, 1/6/1955
# 5959                  North Adams Transcript, 3/18/1898
# 325                                Fox News, 12/11/2015
# ...                                                 ...
# 6119                         Journal of Captain Marryat
# 6133                             The Observer 5/28/1797
# 6137  H.R. Janisch (1885), Extracts from the St. Hel...
# 6155                                     C. Moore, GSAF
# 6175  Perils mentioned by Pliny the Elder (23 A.D. t...
#
#                                    pdf  \
# 6049         1846.08.30.R-Marryatt.pdf
# 6058          1844.07.16.R-Algeria.pdf
# 4316           1954.12.29-Mizokawa.pdf
# 5959  1863.00.00.R4-AndamanIslands.pdf
# 325               2015.12.19-Aruba.pdf
# ...                                ...
# 6119        1811.03.01-John-Walker.pdf
# 6133       1797.05.28.R-Cloverdale.pdf
# 6137           1787.07.05-Hicksled.pdf
# 6155       1742.12.17-AdviceSeamen.pdf
# 6175                    77AD-Pliny.pdf
#
#                                                    href  original order  \
# 6049  http://sharkattackfile.net/spreadsheets/pdf_di...           254.0
# 6058  http://sharkattackfile.net/spreadsheets/pdf_di...           245.0
# 4316  http://sharkattackfile.net/spreadsheets/pdf_di...          1987.0
# 5959  http://sharkattackfile.net/spreadsheets/pdf_di...           344.0
# 325   http://sharkattackfile.net/spreadsheets/pdf_di...          5978.0
# ...                                                 ...             ...
# 6119  http://sharkattackfile.net/spreadsheets/pdf_di...           184.0
# 6133  http://sharkattackfile.net/spreadsheets/pdf_di...           170.0
# 6137  http://sharkattackfile.net/spreadsheets/pdf_di...           166.0
# 6155  http://sharkattackfile.net/spreadsheets/pdf_di...           148.0
# 6175  http://sharkattackfile.net/spreadsheets/pdf_di...           128.0
#
#      Sobrevivio
# 6049        Yes
# 6058        Yes
# 4316        Yes
# 5959        Yes
# 325         Yes
# ...         ...
# 6119        Yes
# 6133        Yes
# 6137        Yes
# 6155        Yes
# 6175        Yes
#
# [802 rows x 20 columns]

# %%
sns.catplot(x = 'Injury', kind="count", data=fatal , hue = 'Sex',palette = 'winter')

# %% [markdown]
#  # 6.) Los tiburones tienen especial predilección por los surferos?

# %%
surferos[surferos['Sobrevivio']== 'Yes']
# Out:
#        Case Number         Date    Year        Type       Country  \
# 2004    2000.09.25  25-Sep-2000  2000.0  Unprovoked     AUSTRALIA
# 2005    2000.09.24  24-Sep-2000  2000.0  Unprovoked     AUSTRALIA
# 996     2010.08.17  17-Aug-2010  2010.0  Unprovoked     AUSTRALIA
# 1657    2004.07.10  10-Jul-2004  2004.0  Unprovoked     AUSTRALIA
# 5235    1922.01.04  04-Jan-1922  1922.0  Unprovoked     AUSTRALIA
# 2985    1982.03.07  07-Mar-1982  1982.0  Unprovoked     AUSTRALIA
# 271     2016.05.31  31-May-2016  2016.0  Unprovoked     AUSTRALIA
# 448     2015.02.09  09-Feb-2015  2015.0  Unprovoked     AUSTRALIA
# 3868  1961.12.18.a  18-Dec-1961  1961.0  Unprovoked     AUSTRALIA
# 3244    1975.01.19  19-Jan-1975  1975.0  Unprovoked     AUSTRALIA
# 155   2017.04.17.a  17-Apr-2017  2017.0  Unprovoked     AUSTRALIA
# 2690    1989.03.09  09-Mar-1989  1989.0  Unprovoked     AUSTRALIA
# 599   2013.11.23.a  23-Nov-2013  2013.0  Unprovoked     AUSTRALIA
# 2531    1992.10.01  01-Oct-1992  1992.0  Unprovoked     AUSTRALIA
# 765     2012.07.14  14-Jul-2012  2012.0  Unprovoked     AUSTRALIA
# 2412    1994.12.01  01-Dec-1994  1994.0  Unprovoked        BRAZIL
# 1807    2002.12.01  01-Dec-2002  2002.0  Unprovoked        BRAZIL
# 2155  1998.11.02.a  02-Nov-1998  1998.0  Unprovoked        BRAZIL
# 2371    1995.07.07  07-Jul-1995  1995.0  Unprovoked        BRAZIL
# 909   2011.06.19.a  19-Jun-2011  2011.0  Unprovoked     COSTARICA
# 2473  1993.09.16.a  16-Sep-1993  1993.0  Unprovoked    ELSALVADOR
# 1257    2008.05.23  23-May-2008  2008.0  Unprovoked        MEXICO
# 1263  2008.04.28.b  28-Apr-2008  2008.0  Unprovoked        MEXICO
# 3365    1971.04.06   6-Apr-1971  1971.0  Unprovoked        MEXICO
# 1150    2009.03.06  06-Mar-2009  2009.0  Unprovoked  NEWCALEDONIA
# 1987    2000.12.00     Dec-2000  2000.0  Unprovoked    NEWZEALAND
# 2007  2000.09.16.b  16-Sep-2000  2000.0  Unprovoked       OKINAWA
# 762     2012.07.23  23-Jul-2012  2012.0  Unprovoked       REUNION
# 2676    1989.07.19  19-Jul-1989  1989.0  Unprovoked       REUNION
# 434     2015.04.12  12-Apr-2015  2015.0  Unprovoked       REUNION
# 2548  1992.06.28.a  28-Jun-1992  1992.0  Unprovoked       REUNION
# 2553    1992.05.22  22-May-1992  1992.0  Unprovoked       REUNION
# 2325    1996.01.10  10-Jan-1996  1996.0  Unprovoked       REUNION
# 1444  2006.08.20.a  20-Aug-2006  2006.0  Unprovoked       REUNION
# 1408    2007.01.14  14-Jan-2007  2007.0  Unprovoked   SOUTHAFRICA
# 2978    1982.06.29  29-Jun-1982  1982.0  Unprovoked   SOUTHAFRICA
# 2207  1998.00.00.c         1998  1998.0  Unprovoked   SOUTHAFRICA
# 879     2011.08.23  23-Aug-2011  2011.0  Unprovoked   SOUTHAFRICA
# 2428  1994.07.09.b  09-Jul-1994  1994.0  Unprovoked   SOUTHAFRICA
# 2242    1997.07.21  21-Jul-1997  1997.0  Unprovoked   SOUTHAFRICA
# 1142    2009.03.21  21-Mar-2009  2009.0  Unprovoked   SOUTHAFRICA
# 1096    2009.08.29  29-Aug-2009  2009.0  Unprovoked   SOUTHAFRICA
# 954     2011.01.15  15-Jan-2011  2011.0  Unprovoked   SOUTHAFRICA
# 1549    2005.09.11  11-Sep-2005  2005.0  Unprovoked           USA
# 6097    1828.00.00         1828  1828.0  Unprovoked           USA
# 6143    1779.00.00         1779  1779.0  Unprovoked           USA
# 728     2012.10.23  23-Oct-2012  2012.0  Unprovoked           USA
# 4130    1958.12.13  13-Dec-1958  1958.0  Unprovoked           USA
# 3800    1962.08.19  19-Aug-1962  1962.0  Unprovoked           USA
# 2999    1981.12.19  19-Dec-1981  1981.0  Unprovoked           USA
# 1680    2004.04.07  07-Apr-2004  2004.0  Unprovoked           USA
# 2461    1993.12.00     Dec-1993  1993.0  Unprovoked           USA
# 2454  1994.01.31.a  31-Jan-1994  1994.0  Unprovoked           USA
#
#                         Area  \
# 2004         South Australia
# 2005         South Australia
# 996        Western Australia
# 1657       Western Australia
# 5235         New South Wales
# 2985         New South Wales
# 271        Western Australia
# 448          New South Wales
# 3868              Queensland
# 3244         South Australia
# 155        Western Australia
# 2690         South Australia
# 599        Western Australia
# 2531              Queensland
# 765        Western Australia
# 2412              Pernambuco
# 1807              Pernambuco
# 2155              Pernambuco
# 2371              Pernambuco
# 909               Guanacaste
# 2473             La Libertad
# 1257                  Guerro
# 1263                  Guerro
# 3365                Guerrero
# 1150          South Province
# 1987            Cook Islands
# 2007           Miyako Island
# 762            Trois-Bassins
# 2676          Sainte-Suzanne
# 434   Saint-Gilles-les-Bains
# 2548              Saint-Paul
# 2553            Saint-Joseph
# 2325             Saint-Paul
# 1444            Saint-Pierre
# 1408   Eastern Cape Province
# 2978   Eastern Cape Province
# 2207   Eastern Cape Province
# 879    Western Cape Province
# 2428   Eastern Cape Province
# 2242   Eastern Cape Province
# 1142   Eastern Cape Province
# 1096   Western Cape Province
# 954    Eastern Cape Province
# 1549          South Carolina
# 6097                  Hawaii
# 6143                  Hawaii
# 728               California
# 4130                  Hawaii
# 3800                   Texas
# 2999              California
# 1680                  Hawaii
# 2461                  Hawaii
# 2454                  Hawaii
#
#                                                Location  \
# 2004                        Black Point, Eyre Peninsula
# 2005                           Cactus Beach near Penong
# 996                                       Cowaramup Bay
# 1657                  Lefthanders Beach, Margaret River
# 5235                          Stockton Beach, Newcastle
# 2985                            Tallow Beach, Byron Bay
# 271                              Falcon Beach, Mandurah
# 448                                        Shelly Beach
# 3868                                        Noosa Heads
# 3244                                         Coffin Bay
# 155                              Kelpies near Wylie Bay
# 2690  Waitpinga Beach, near Victor Harbor, Encounter...
# 599                                           Gracetown
# 2531                  North Point Beach, Moreton Island
# 765                                    Off Wedge Island
# 2412                                              Paiva
# 1807                           Boa Viagem Beach, Recife
# 2155                           Boa Viagem Beach, Recife
# 2371                                           Candeias
# 909                                        Playa Grande
# 2473                                     El Cocal Beach
# 1257                                       Pantla Beach
# 1263                                    Troncones Beach
# 3365                         Copacabana Beach, Acapulco
# 1150                                            Bourail
# 1987                                Arorangi, Rarotonga
# 2007                                     Sunayama Beach
# 762                                                 NaN
# 2676                                     Temple Tamoule
# 434                                          Cap Homard
# 2548                                 Cap de la Marianne
# 2553                                   Lieu-dit Cayenne
# 2325                Embouchure de l'étang de Saint Paul
# 1444                                   Pointe du Diable
# 1408                      Second Beach, Port St. John's
# 2978                                      Ntlonyana Bay
# 2207                                   Hole-in-the Wall
# 879   Lookout Beach, near the Keurbooms river mouth ...
# 2428                          Nahoon Beach, East London
# 2242                            Breezy Point, Ntlonyana
# 1142                      Second Beach, Port St. John's
# 1096                                           Glentana
# 954                       Second Beach, Port St. John's
# 1549                                        Folly Beach
# 6097                                  Uo, Lahaina, Maui
# 6143                                     Maliu, Hawai'i
# 728            Surf Beach, Lompoc, Santa Barbara County
# 4130  Near Twin Islands off Lanikai, O'ahu (east coast)
# 3800  Off Andy Bowie Park, Padre Island, near Port I...
# 2999  South Moss Beach, Spanish Bay, Monterey Peninsula
# 1680                                 Kahana Beach, Maui
# 2461                                              Waipo
# 2454                    Velzyland, north shore of O'ahu
#
#                               Activity                                  Name  \
# 2004                           Surfing                          Jevan Wright
# 2005                           Surfing                         Cameron Bayes
# 996                            Surfing                      Nicholas Edwards
# 1657                           Surfing                  Bradley Adrian Smith
# 5235                           Surfing                     John Manning Rowe
# 2985                           Surfing                            Allan Ford
# 271                            Surfing                           Ben Gerring
# 448                            Surfing                      Tadashi Nakahara
# 3868     Surfing, pushing board ashore                  John Grayson Andrews
# 3244                           Surfing                       David Barrowman
# 155                            Surfing                      Laeticia Brouwer
# 2690                           Surfing                         Matthew Foale
# 599                            Surfing                            Chris Boyd
# 2531                           Surfing                      Michael Docherty
# 765                            Surfing                            Ben Linden
# 2412                           Surfing             Laudenilson Gomes de Lima
# 1807                           Surfing                        Aylson Gadelha
# 2155                           Surfing  Claudio Roberto Florencio de Freitas
# 2371                           Surfing           Clélio Rosendo Falcão Filho
# 909                            Surfing                          Kevin Moraga
# 2473                           Surfing             Mauricio Guzman Castaneda
# 1257                           Surfing              Osvaldo Mata Valdovinos
# 1263                           Surfing                           Adrian Ruiz
# 3365                           Surfing                            Jimmy Rowe
# 1150                           Surfing                       Kevin Hannecart
# 1987                           Surfing                                female
# 2007                           Surfing                        Takayuki Miura
# 762                            Surfing                     Alexandre Rassiga
# 2676                           Surfing                         Bruno Giraud
# 434                            Surfing                         Elio Canestri
# 2548                           Surfing                      Theirry Mercredi
# 2553                           Surfing                      Emmanuel Nativel
# 2325                           Surfing                       Grégory Bénèche
# 1444                           Surfing                       Sébastien Émond
# 1408           Swimming / Body Surfing                       Sibulele Masiza
# 2978                           Surfing                            Alex Macun
# 2207                           Surfing                                    M
#
# 879                            Surfing                       Tim van Heerden
# 2428                           Surfing                           Bruce Corby
# 2242                           Surfing                          Mark Penches
# 1142                           Surfing                        Luyolo Mangele
# 1096                           Surfing                       Gerhard van Zyl
# 954                            Surfing                          Zama Ndamase
# 1549                           Surfing                     Greg  Norton, Jr.
# 6097                           Surfing                                  Male
# 6143                           Surfing                      Nu'u-anu-pa'a hu
# 728                            Surfing           Francisco Javier Solorio Jr
# 4130           Surfing on air mattress                     William S. Weaver
# 3800  Surf fishing in waist-deep water                              Hans Fix
# 2999                           Surfing                           Lewis Boren
# 1680                           Surfing                        Willis McInnis
# 2461                           Surfing                       Daniel McMoyler
# 2454                           Surfing                            Jim Broach
#
#      Sex    Age                                             Injury  \
# 2004   M     17                                              FATAL
# 2005   M     25                                              FATAL
# 996    M     31                                              FATAL
# 1657   M     30          FATAL, abdomen, pelvis & leg bitten
# 5235   M     26  FATAL, disappeared, then his shark-bitten rema...
# 2985   M     20                                 Legs bitten  FATAL
# 271    M     29                                              FATAL
# 448    M     41                                              FATAL
# 3868   M     22  FATAL, right wrist and hand bitten, left leg s...
# 3244   M     17                          FATAL, body not recovered
# 155    F     17                                              FATAL
# 2690   M     27                                 Thigh bitten FATAL
# 599    M     35                                              FATAL
# 2531   M     28                                              FATAL
# 765    M     24                                              FATAL
# 2412   M    NaN                                              FATAL
# 1807   M     19                                              FATAL
# 2155   M     22                      FATAL, left forearm severed
# 2371   M     18                                  Arm bitten, FATAL
# 909    M     15                                              FATAL
# 2473   M     17           FATAL, arms & legs bitten, then drowned
# 1257   M     21                                              FATAL
# 1263   M     24                FATAL    Severe bite to right thigh
# 3365   M     19                          FATAL, left thigh bitten
# 1150   M     19                                              FATAL
# 1987   F    NaN                                              FATAL
# 2007   M     31                                              FATAL
# 762    M     22                                              FATAL
# 2676   M    NaN                                              FATAL
# 434    M     13                                              FATAL
# 2548   M     16                                              FATAL
# 2553   M    NaN                                              FATAL
# 2325   M     25                                              FATAL
# 1444   M     34                                              FATAL
# 1408   M     24                 Presumed FATAL, body not recovered
# 2978   M     27                                              FATAL
# 2207   M     28                                              FATAL
# 879    M     49                                              FATAL
# 2428   M     22                                FATAL, leg severed
# 2242   M     25                                              FATAL
# 1142   M     16                                              FATAL
# 1096   M     25                                              FATAL
# 954    M     16                                              FATAL
# 1549   M     18                                              FATAL
# 6097   M    NaN                                              FATAL
# 6143   M  young                         FATAL, buttock lacerated
# 728    M     39                                              FATAL
# 4130   M     15                               FATAL, leg severed
# 3800   M     40                      FATAL, lower right leg bitten
# 2999   M     24                               FATAL, torso bitten
# 1680   M     57           FATAL Severe wound to right thigh & calf
# 2461   M    NaN                                              FATAL
# 2454   M    NaN                                              FATAL
#
#      Survived (Y/N)            Time  \
# 2004              Y           13h00
# 2005              Y           07h30
# 996               Y           08h05
# 1657              Y           14h10
# 5235              Y         Evening
# 2985              Y           12h00
# 271               Y           16h00
# 448               Y           10h00
# 3868              Y           06h15
# 3244              Y             NaN
# 155               Y           16h00
# 2690              Y           20h15
# 599               Y           09h00
# 2531              Y           14h30
# 765               Y           09h05
# 2412              Y             NaN
# 1807              Y             NaN
# 2155              Y  Late afternoon
# 2371              Y             NaN
# 909               Y           12h15
# 2473              Y             NaN
# 1257              Y             NaN
# 1263              Y       Afternoon
# 3365              Y           11h00
# 1150              Y           11h30
# 1987              Y             NaN
# 2007              Y           17h00
# 762               Y           16h30
# 2676              Y    17h00 Sunset
# 434               Y           09h00
# 2548              Y           14h30
# 2553              Y           14h00
# 2325              Y           16h00
# 1444              Y           11h00
# 1408              Y       Afternoon
# 2978              Y           09h30
# 2207              Y             NaN
# 879               Y           09h11
# 2428              Y           13h26
# 2242              Y           12h45
# 1142              Y       Afternoon
# 1096              Y           15h30
# 954               Y           12h30
# 1549              Y           14h00
# 6097              Y             NaN
# 6143              Y             NaN
# 728               Y           11h00
# 4130              Y           13h00
# 3800              Y           15h30
# 2999              Y         Evening
# 1680              Y           07h08
# 2461              Y             NaN
# 2454              Y             NaN
#
#                                                Species   \
# 2004                                        White shark
# 2005            White shark, 4 m to 5 m [13' to 16.5']
# 996                                         White shark
# 1657                             2 sharks, 4.5 m & 3 m
# 5235                                                NaN
# 2985                                                NaN
# 271                                         White shark
# 448                                    3.5 to 4 m shark
# 3868  Next morning a 3 m [10'] shark was caught that...
# 3244                                                NaN
# 155                                         White shark
# 2690                            2 m [6.75'] white shark
# 599                    Thought to involve a white shark
# 2531                                  4.2 m white shark
# 765                                     White shark, 5m
# 2412                                                NaN
# 1807                                                NaN
# 2155                    Though to involve a white shark
# 2371                                                NaN
# 909                                                 NaN
# 2473                                                NaN
# 1257                                          2 m shark
# 1263                                        Tiger shark
# 3365                                                NaN
# 1150                                                NaN
# 1987                                                NaN
# 2007                                White shark, 2.5 m
# 762                                                 NaN
# 2676                                                NaN
# 434                                          Bull shark
# 2548                          Bull shark or lemon shark
# 2553              Tiger shark, 3 m to 4 m [10' to 13']
# 2325                      Tiger shark, 300-kg [662-lb]
# 1444                                                NaN
# 1408                                        Tiger shark
# 2978  2.4 m [8'] white shark, species identity confi...
# 2207                                                NaN
# 879                                    White shark, >6'
# 2428                              4 m [13'] white shark
# 2242                                  4.5 m white shark
# 1142                                                NaN
# 1096                                        White shark
# 954                                                 NaN
# 1549                                                NaN
# 6097                                                NaN
# 6143                                                NaN
# 728                            White shark, 15' to 16'
# 4130          Tiger shark, 4.6 m to 7.6 m [15' to 25']
# 3800                                            Unknown
# 2999                              7 m [23'] white shark
# 1680                                        Tiger shark
# 2461  On 11-Jan-1994, his remains washed ashore. A 2...
# 2454                                        Tiger shark
#
#                                  Investigator or Source  \
# 2004                                     T. Peake, GSAF
# 2005                                     T. Peake, GSAF
# 996                           The Australian, 8/17/2010
# 1657                                     T. Peake, GSAF
# 5235    The Argus, 1/9/1922; V.M. Coppleson (1933), N15
# 2985                             A. Sharpe, pp.4, 86-87
# 271                                Perth Now, 5/31/2016
# 448                             The Telegraph, 2/9/2015
# 3868  Natal Daily News, 12/19/1961; Sydney Morning H...
# 3244  J. West; Adelaide Advertiser, 1/20/1975; P. Ke...
# 155                                      B. Myatt, GSAF
# 2690       Courier-Mail, 3/11/1989, p.5;  J. West, ASAF
# 599                     J. Baily; Perth Now, 11/23/2013
# 2531  Daily Telegraph (Sydney) 10/2/1992 ; Orlando S...
# 765                                  WA News, 7/15/2012
# 2412            San Jose Mercury News, 1/6/1995, p.12A
# 1807                                           O. Gadig
# 2155                                O. Gadig & A. Xureb
# 2371                                           JCOnline
# 909                  D. Martinez, Tico Times, 6/21/2011
# 2473                           Tampa Tribune, 9/18/1993
# 1257                                            Reuters
# 1263                                       Surfline.com
# 3365                                 A.Resciniti, p.109
# 1150           Les Nouvelles Caledoniennes, 3/7-10/2009
# 1987                          C. Tini, R.D. Weeks, GSAF
# 2007                        M. Shimbun; japanupdate.com
# 762                             Clicanoo.re, 7/23/20122
# 2676       Clicanoo, le journal  de l'Ile de la Réunion
# 434                       Le Huffington Post, 4/15/2015
# 2548                                 G. Van Grevelynghe
# 2553                                 G. Van Grevelynghe
# 2325       Clicanoo, le journal  de l'Ile de la Réunion
# 1444                                         P. Immerz
# 1408  G. Cliff, Natal Sharks Board; East London Disp...
# 2978  M. Levine, GSAF; R.B. Wilson, B. Davis, NSB; T...
# 2207                                 BL Meel / B. Myatt
# 879                                   News24, 8/23/2011
# 2428                                    A Gifford, GSAF
# 2242                    A. Gifford, GSAF, G. Cliff, NSB
# 1142                          Daily Dispatch, 3/22/2009
# 1096                         Cape Argus, 8/30/2009, p.1
# 954                               The Mercury, 1/15/211
# 1549                          Post & Courier, 9/12/2005
# 6097          J. Borg, p.68; L. Taylor (1993), pp.94-95
# 6143  G.H. Balazs; J. Borg, p.68; L. Taylor (1993), ...
# 728                                          R. Collier
# 4130                                       A. L. Tester
# 3800                               J. A. Hockaday, M.D.
# 2999  R.N. Lea & D. Miller; R. Collier, pp.84-85; A....
# 1680       L. Fujimoto, B. Perry & M. Tanji, Maui News
# 2461                                  Allen, pp.109-110
# 2454                            G. Balazs; Allen, p.109
#
#                                         pdf  \
# 2004                  2000.09.25-Wright.pdf
# 2005                   2000.09.24-Bayes.pdf
# 996                  2010.08.17-Edwards.pdf
# 1657               2004.07.10-BradSmith.pdf
# 5235            1922.01.04-JManningRowe.pdf
# 2985               1982.03.07-AllenFord.pdf
# 271                  2016.05.31-Gerring.pdf
# 448                 2015.02.09-Nakahara.pdf
# 3868               1961.12.18.a-Andrews.pdf
# 3244               1975.01.19-Barrowman.pdf
# 155                2017.04.17.a Brouwer.pdf
# 2690                   1989.03.09-Foale.pdf
# 599                   2013.11.23.a-Boyd.pdf
# 2531                1992.10.01-Docherty.pdf
# 765                   2012.07.14-Linden.pdf
# 2412  1994.12.01-LaudenilsonGomesDeLima.pdf
# 1807                 2002.12.01-Gadelha.pdf
# 2155             1998.11.02.a-deFrietas.pdf
# 2371                  1995.07.07-Filhol.pdf
# 909                 2011.06.19.a-Moraga.pdf
# 2473             1993.09.16.a-Castaneda.pdf
# 1257                    2008.05.23-Mata.pdf
# 1263                  2008.04.28.b-Ruiz.pdf
# 3365                    1971.04.06-Rowe.pdf
# 1150               2009.03.06-Hannecart.pdf
# 1987              2000.12.00 - Arorangi.pdf
# 2007                 2000.09.16.b-Miura.pdf
# 762                  2012.07.23-Rassica.pdf
# 2676                  1989.07.19-Giraud.pdf
# 434                 2015.04.12-Canestri.pdf
# 2548              1992.06.28.a-Mercredi.pdf
# 2553                 1992.05.22-Nativel.pdf
# 2325                 1996.01.10-Beneche.pdf
# 1444                   2006.08.20-Emond.pdf
# 1408                  2007.01.14-Masiza.pdf
# 2978                   1982.06.29-Macun.pdf
# 2207              1998.00.00.c-Transkei.pdf
# 879               2011.08.23-VanHeerden.pdf
# 2428                 1994.07.09.b-Corby.pdf
# 2242                 1997.07.21-Penches.pdf
# 1142                 2009.03.21-Mangele.pdf
# 1096                  2009.08.29-VanZyl.pdf
# 954                  2011.01.15-Ndamase.pdf
# 1549                  2005.09.11-Norton.pdf
# 6097                    1828.00.00-male.pdf
# 6143                  1779.00.00-Hawaii.pdf
# 728                  2012.10.23-Solorio.pdf
# 4130                  1958.12.13-Weaver.pdf
# 3800                     1962.08.19-Fix.pdf
# 2999           1981.12.19-Boren_Collier.pdf
# 1680                 2004.04.07-McInnis.pdf
# 2461                1993.12.00-McMoyler.pdf
# 2454                1994.01.31.a-Broach.pdf
#
#                                                    href  original order  \
# 2004  http://sharkattackfile.net/spreadsheets/pdf_di...          4299.0
# 2005  http://sharkattackfile.net/spreadsheets/pdf_di...          4298.0
# 996   http://sharkattackfile.net/spreadsheets/pdf_di...          5307.0
# 1657  http://sharkattackfile.net/spreadsheets/pdf_di...          4646.0
# 5235  http://sharkattackfile.net/spreadsheets/pdf_di...          1068.0
# 2985  http://sharkattackfile.net/spreadsheets/pdf_di...          3318.0
# 271   http://sharkattackfile.net/spreadsheets/pdf_di...          6032.0
# 448   http://sharkattackfile.net/spreadsheets/pdf_di...          5855.0
# 3868  http://sharkattackfile.net/spreadsheets/pdf_di...          2435.0
# 3244  http://sharkattackfile.net/spreadsheets/pdf_di...          3059.0
# 155   http://sharkattackfile.net/spreadsheets/pdf_di...          6148.0
# 2690  http://sharkattackfile.net/spreadsheets/pdf_di...          3613.0
# 599   http://sharkattackfile.net/spreadsheets/pdf_di...          5704.0
# 2531  http://sharkattackfile.net/spreadsheets/pdf_di...          3772.0
# 765   http://sharkattackfile.net/spreadsheets/pdf_di...          5538.0
# 2412  http://sharkattackfile.net/spreadsheets/pdf_di...          3891.0
# 1807  http://sharkattackfile.net/spreadsheets/pdf_di...          4496.0
# 2155  http://sharkattackfile.net/spreadsheets/pdf_di...          4148.0
# 2371  http://sharkattackfile.net/spreadsheets/pdf_di...          3932.0
# 909   http://sharkattackfile.net/spreadsheets/pdf_di...          5394.0
# 2473  http://sharkattackfile.net/spreadsheets/pdf_di...          3830.0
# 1257  http://sharkattackfile.net/spreadsheets/pdf_di...          5046.0
# 1263  http://sharkattackfile.net/spreadsheets/pdf_di...          5040.0
# 3365  http://sharkattackfile.net/spreadsheets/pdf_di...          2938.0
# 1150  http://sharkattackfile.net/spreadsheets/pdf_di...          5153.0
# 1987  http://sharkattackfile.net/spreadsheets/pdf_di...          4316.0
# 2007  http://sharkattackfile.net/spreadsheets/pdf_di...          4296.0
# 762   http://sharkattackfile.net/spreadsheets/pdf_di...          5541.0
# 2676  http://sharkattackfile.net/spreadsheets/pdf_di...          3627.0
# 434   http://sharkattackfile.net/spreadsheets/pdf_di...          5869.0
# 2548  http://sharkattackfile.net/spreadsheets/pdf_di...          3755.0
# 2553  http://sharkattackfile.net/spreadsheets/pdf_di...          3750.0
# 2325  http://sharkattackfile.net/spreadsheets/pdf_di...          3978.0
# 1444  http://sharkattackfile.net/spreadsheets/pdf_di...          4859.0
# 1408  http://sharkattackfile.net/spreadsheets/pdf_di...          4895.0
# 2978  http://sharkattackfile.net/spreadsheets/pdf_di...          3325.0
# 2207  http://sharkattackfile.net/spreadsheets/pdf_di...          4096.0
# 879   http://sharkattackfile.net/spreadsheets/pdf_di...          5424.0
# 2428  http://sharkattackfile.net/spreadsheets/pdf_di...          3875.0
# 2242  http://sharkattackfile.net/spreadsheets/pdf_di...          4061.0
# 1142  http://sharkattackfile.net/spreadsheets/pdf_di...          5161.0
# 1096  http://sharkattackfile.net/spreadsheets/pdf_di...          5207.0
# 954   http://sharkattackfile.net/spreadsheets/pdf_di...          5349.0
# 1549  http://sharkattackfile.net/spreadsheets/pdf_di...          4754.0
# 6097  http://sharkattackfile.net/spreadsheets/pdf_di...           206.0
# 6143  http://sharkattackfile.net/spreadsheets/pdf_di...           160.0
# 728   http://sharkattackfile.net/spreadsheets/pdf_di...          5575.0
# 4130  http://sharkattackfile.net/spreadsheets/pdf_di...          2173.0
# 3800  http://sharkattackfile.net/spreadsheets/pdf_di...          2503.0
# 2999  http://sharkattackfile.net/spreadsheets/pdf_di...          3304.0
# 1680  http://sharkattackfile.net/spreadsheets/pdf_di...          4623.0
# 2461  http://sharkattackfile.net/spreadsheets/pdf_di...          3842.0
# 2454  http://sharkattackfile.net/spreadsheets/pdf_di...          3849.0
#
#      Sobrevivio
# 2004        Yes
# 2005        Yes
# 996         Yes
# 1657        Yes
# 5235        Yes
# 2985        Yes
# 271         Yes
# 448         Yes
# 3868        Yes
# 3244        Yes
# 155         Yes
# 2690        Yes
# 599         Yes
# 2531        Yes
# 765         Yes
# 2412        Yes
# 1807        Yes
# 2155        Yes
# 2371        Yes
# 909         Yes
# 2473        Yes
# 1257        Yes
# 1263        Yes
# 3365        Yes
# 1150        Yes
# 1987        Yes
# 2007        Yes
# 762         Yes
# 2676        Yes
# 434         Yes
# 2548        Yes
# 2553        Yes
# 2325        Yes
# 1444        Yes
# 1408        Yes
# 2978        Yes
# 2207        Yes
# 879         Yes
# 2428        Yes
# 2242        Yes
# 1142        Yes
# 1096        Yes
# 954         Yes
# 1549        Yes
# 6097        Yes
# 6143        Yes
# 728         Yes
# 4130        Yes
# 3800        Yes
# 2999        Yes
# 1680        Yes
# 2461        Yes
# 2454        Yes

# %%
surferos= attack[attack['Activity'].str.contains('Surf') == True]
#attack[attack['Activity'].fillna(0)
#attack['Activity'].str.contains('Surf', na=False)

# %%
sns.set(style='ticks')
plt.style.use('fivethirtyeight')

# %%
plt.figure(figsize=(10,7))
sns.kdeplot('Year', data = surferos , hue = 'Sobrevivio', shade = True ,alpha=.5)
plt.xlim(1900, 2080)
plt.title('Surfistas',fontsize= 50)
# Out:
# Text(0.5, 1.0, 'Surfistas')

# %% [markdown]
# # 7.)Reunion Island es el lugar del mundo donde ocurren más ataques de tiburón en terminos relativos.

# %%
cant_ataques= attack.groupby('Country')[['Survived (Y/N)']].count().sort_values(by='Survived (Y/N)').tail(20)
cant_ataques
# Out:
#                 Survived (Y/N)
# Country
# PANAMA                      31
# SPAIN                       34
# EGYPT                       37
# INDIA                       39
# MOZAMBIQUE                  41
# CUBA                        42
# NAN                         45
# NEWCALEDONIA                52
# ITALY                       57
# PHILIPPINES                 58
# REUNION                     60
# FIJI                        64
# MEXICO                      79
# BRAZIL                     104
# BAHAMAS                    104
# NEWZEALAND                 116
# PAPUANEWGUINEA             132
# SOUTHAFRICA                515
# AUSTRALIA                 1225
# USA                       2041

# %%
cant_ataques.plot(kind = 'bar' , color = 'b' )
plt.title('Mayor cantidad de Muertes')
# Out:
# Text(0.5, 1.0, 'Mayor cantidad de Muertes')

# %%
attack[attack['Country'].str.contains('REUNION')]
# Out:
#        Case Number                 Date    Year        Type        Country  \
# 2016  2000.09.08.a          08-Sep-2000  2000.0  Unprovoked        REUNION
# 2126    1999.04.11          11-Apr-1999  1999.0  Unprovoked        REUNION
# 388     2015.07.22          22-Jul-2015  2015.0  Unprovoked        REUNION
# 6218       ND.0096              No date     0.0  Unprovoked        REUNION
# 6278       ND.0024  Between 1918 & 1939     0.0  Unprovoked        REUNION
# ...            ...                  ...     ...         ...            ...
# 846     2011.11.11          11-Nov-2011  2011.0  Unprovoked        REUNION
# 1035    2010.03.27          27-Mar-2010  2010.0  Unprovoked        REUNION
# 2160  1998.10.01.b          01-Oct-1998  1998.0  Unprovoked        REUNION
# 2261    1997.02.20          20-Feb-1997  1997.0  Unprovoked        REUNION
# 5513  1904.00.00.R                 1904  1904.0  Unprovoked  REUNIONISLAND
#
#                          Area                                    Location  \
# 2016             Saint-Pierre                              Pic du Diable
# 2126  L' Etang Salé-les-Bains                           Roche-aux-Oiseaux
# 388                       NaN                                     St. Leu
# 6218               Grand'Anse                                  Petite-île
# 6278              Saint-Denis                                   Barachois
# ...                       ...                                         ...
# 846               Bois-Blanc                                  Sainte-Rose
# 1035             Saint-Benoit                                     Bittern
# 2160             Saint-Benoît                                         NaN
# 2261             L'Etang-Sale                                         NaN
# 5513                      NaN  Swimming off the British steamer Troutpool
#
#                                                Activity                 Name  \
# 2016                                            Surfing           Karim Maan
# 2126  Swimming after being swept into sea by a large...            Guy Oudin
# 388                                             Surfing    Rodolphe Arriéguy
# 6218                              yachtsman in a zodiac                  NaN
# 6278                                           Swimming                  NaN
# ...                                                 ...                  ...
# 846                          Free diving / spearfishing   Jean-Paul Delaunay
# 1035                                            Surfing   Oliver Schorebreak
# 2160                                             Diving                  NaN
# 2261                                                NaN        Laurent Lebon
# 5513                                           Swimming  James C. Stonehouse
#
#       Sex  Age                   Injury Survived (Y/N)     Time  \
# 2016    M   27          Left arm bitten              N    18h05
# 2126    M   52                    FATAL              Y    10h30
# 388     M   45               Arm bitten              N      NaN
# 6218    M  NaN                 Survived              N      NaN
# 6278  NaN  NaN                    FATAL              Y      NaN
# ...   ...  ...                      ...            ...      ...
# 846     M   42         Left foot bitten              N  Morning
# 1035    M   34  No injury, board bitten              N    11h00
# 2160  NaN  NaN                 Survived              N      NaN
# 2261    M  NaN             Hand injured              N      NaN
# 5513    M   16                    FATAL              Y      NaN
#
#                      Species   \
# 2016  Tiger shark, 3 m [10']
# 2126            3 bull sharks
# 388            Bull shark, 2m
# 6218                      NaN
# 6278                      NaN
# ...                       ...
# 846                       NaN
# 1035              1.5 m shark
# 2160                      NaN
# 2261                      NaN
# 5513                      NaN
#
#                                  Investigator or Source  \
# 2016  Clicanoo, le journal  de l'Ile de la Réunion; ...
# 2126                                 G. Van Grevelynghe
# 388                            Zig Zag Surfing Magazine
# 6218                                 G. Van Grevelynghe
# 6278                                 G. Van Grevelynghe
# ...                                                 ...
# 846   H. Nickel & A. Brenneka, SharkAttackSurvivors.com
# 1035                                 C. Ekstander, GSAF
# 2160                                 G. Van Grevelynghe
# 2261                             LeQuotidien, 12/4/1999
# 5513                                     C. Moore, GSAF
#
#                                 pdf  \
# 2016     2000.09.08.a-KarimMaan.pdf
# 2126           1999.04.11-Oudin.pdf
# 388         2015.07.22-Arrieguy.pdf
# 6218     ND-0096-Zodiac-Reunion.pdf
# 6278  ND-0024-Barachois-Reunion.pdf
# ...                             ...
# 846         2011.11.11-Delaunay.pdf
# 1035     2010.03.27-Schorebreak.pdf
# 2160       1998.10.01.b-Reunion.pdf
# 2261           1997.02.20-Lebon.pdf
# 5513    1904.00.00.R-Stonehouse.pdf
#
#                                                    href  original order  \
# 2016  http://sharkattackfile.net/spreadsheets/pdf_di...          4287.0
# 2126  http://sharkattackfile.net/spreadsheets/pdf_di...          4177.0
# 388   http://sharkattackfile.net/spreadsheets/pdf_di...          5915.0
# 6218  http://sharkattackfile.net/spreadsheets/pdf_di...            85.0
# 6278  http://sharkattackfile.net/spreadsheets/pdf_di...            25.0
# ...                                                 ...             ...
# 846   http://sharkattackfile.net/spreadsheets/pdf_di...          5457.0
# 1035  http://sharkattackfile.net/spreadsheets/pdf_di...          5268.0
# 2160  http://sharkattackfile.net/spreadsheets/pdf_di...          4143.0
# 2261  http://sharkattackfile.net/spreadsheets/pdf_di...          4042.0
# 5513  http://sharkattackfile.net/spreadsheets/pdf_di...           790.0
#
#      Sobrevivio
# 2016         No
# 2126        Yes
# 388          No
# 6218         No
# 6278        Yes
# ...         ...
# 846          No
# 1035         No
# 2160         No
# 2261         No
# 5513        Yes
#
# [61 rows x 20 columns]

# %% [markdown]
# # 8.) En Sudáfrica hay más ataques letales a mujeres que en Australia?

# %%
ejemplo8= attack[(attack['Country'] == 'AUSTRALIA') | (attack['Country'] == 'SOUTHAFRICA')]
ejemplo8 = ejemplo8[ejemplo8['Sex'] == 'F']

# %%
sns.catplot(x = 'Country', data = ejemplo8, kind = 'count' , hue = 'Sobrevivio' , palette = "rocket")
plt.title('Ataques a Mujeres')
# Out:
# Text(0.5, 1.0, 'Ataques a Mujeres')

# %%
plt.figure(figsize=(30,10));
sns.catplot(x='Sobrevivio', 
           col = 'Country',
           col_wrap = 2,
           data = ejemplo8,
           kind = "count",
           palette = "flare")

# %%
attack.dropna(axis = 0, thresh = 4, inplace = True )

# %%
attack.reset_index()
# Out:
#       index   Case Number          Date    Year          Type  \
# 0      4636  1944.10.26.a   26-Oct-1944  1944.0  Sea Disaster
# 1      1678  2004.04.13.b   13-Apr-2004  2004.0    Unprovoked
# 2      1679  2004.04.13.a   13-Apr-2004  2004.0       Invalid
# 3      2035    2000.07.12   12-Jul-2000  2000.0    Unprovoked
# 4      3786    1962.10.15   15-Oct-1962  1962.0    Unprovoked
# ...     ...           ...           ...     ...           ...
# 6297   6175    0077.00.00      77  A.D.    77.0    Unprovoked
# 6298   6177     0000.0214  Ca. 214 B.C.     0.0    Unprovoked
# 6299   6199       ND-0124   Before 2011     0.0      Provoked
# 6300   6206       ND-0114   Before 2012     0.0    Unprovoked
# 6301   6259       ND.0044     1941-1945     0.0  Sea Disaster
#
#                Country                                  Area  \
# 0          PHILIPPINES  Bernardino Strait near Gulf of Leyte
# 1                TONGA                            Nuku'alofa
# 2                TONGA                            Nuku'alofa
# 3                TONGA                          Minerva Reef
# 4     ADMIRALTYISLANDS                          Manus Island
# ...                ...                                   ...
# 6297               NAN                            Ionian Sea
# 6298               NAN                            Ionian Sea
# 6299               NAN                                   NaN
# 6300               NAN                                   NaN
# 6301               NAN                                   NaN
#
#                                        Location  \
# 0                                           NaN
# 1                    30 nautical miles offshore
# 2                    30 nautical miles offshore
# 3                         Treated at Nuku-alofa
# 4                  Sisi  (west coast of island)
# ...                                         ...
# 6297                                        NaN
# 6298                                        NaN
# 6299                                        NaN
# 6300  In a river feeding into the Bay of Bengal
# 6301                                        NaN
#
#                                                Activity  \
# 0     USS Hoel DD 533 sunk on 10/24/1944 in the Batt...
# 1     Five men on makeshift raft after their 10 m fi...
# 2     Five men on makeshift raft after their 10 m fi...
# 3                                          Scuba diving
# 4                                                   NaN
# ...                                                 ...
# 6297                                      Sponge diving
# 6298                              Ascending from a dive
# 6299                                                NaN
# 6300                                     Netting shrimp
# 6301         A group of survivors on a raft for 17-days
#
#                          Name  ...  Age  \
# 0                       2 men  ...  NaN
# 1                      male 2  ...  NaN
# 2                      male 1  ...  NaN
# 3            Christian Eckoff  ...   69
# 4                    Pasingan  ...   26
# ...                       ...  ...  ...
# 6297                    males  ...  NaN
# 6298  Tharsys, a sponge diver  ...  NaN
# 6299           Phillip Peters  ...  NaN
# 6300           Sametra Mestri  ...  NaN
# 6301                       C.  ...  NaN
#
#                                                  Injury Survived (Y/N)  \
# 0                     FATAL, both were killed by sharks              Y
# 1     Bitten on feet, legs, back & abdomen but survi...              Y
# 2     He was was bitten on the arm by small sharks &...              Y
# 3                                       Left arm bitten              N
# 4                                    Facial lacerations              N
# ...                                                 ...            ...
# 6297                                              FATAL              Y
# 6298                      FATAL, shark/s bit him in two              Y
# 6299        Bitten by captive sharks PROVOKED INCIDENTS              N
# 6300                                       Hand severed              N
# 6301  FATAL, shark leapt into raft and bit the man w...              Y
#
#                 Time                       Species   \
# 0                NaN                            NaN
# 1                NaN                   small sharks
# 2                NaN          Questionable Incident
# 3                NaN  Grey reef shark, 2 m [6.75']
# 4                NaN                            NaN
# ...              ...                            ...
# 6297             NaN                            NaN
# 6298             NaN                            NaN
# 6299             NaN                            NaN
# 6300             NaN                            NaN
# 6301  Late afternoon               1.2 m [4'] shark
#
#                                  Investigator or Source  \
# 0                           Glenn Hatch Parkin, gunner
# 1                         New Zealand Herald, 4/15/2004
# 2                         New Zealand Herald, 4/15/2004
# 3                              www.spearfishingsa.co.za
# 4                                        SAF Case #1116
# ...                                                 ...
# 6297  Perils mentioned by Pliny the Elder (23 A.D. t...
# 6298  Reported by Greek poet, Leonidas of Tarentum (...
# 6299                    Watertown Daily Times, 7/8/2011
# 6300                    National Georgraphic Television
# 6301         G.A. Llano in Airmen Against the Sea, p.69
#
#                                    pdf  \
# 0     1944.10.26.a-2men-incomplete.pdf
# 1               2004.04.13.b-Tonga.pdf
# 2               2004.04.13.a-Tonga.pdf
# 3                2000.07.12-Eckoff.pdf
# 4               1962.10.15-Pasigan.pdf
# ...                                ...
# 6297                    77AD-Pliny.pdf
# 6298                 214BC-Tharsys.pdf
# 6299                ND-0124-Peters.pdf
# 6300           ND-0114-BayOfBengal.pdf
# 6301                     ND-0044-C.pdf
#
#                                                    href original order  \
# 0     http://sharkattackfile.net/spreadsheets/pdf_di...         1667.0
# 1     http://sharkattackfile.net/spreadsheets/pdf_di...         4625.0
# 2     http://sharkattackfile.net/spreadsheets/pdf_di...         4624.0
# 3     http://sharkattackfile.net/spreadsheets/pdf_di...         4268.0
# 4     http://sharkattackfile.net/spreadsheets/pdf_di...         2517.0
# ...                                                 ...            ...
# 6297  http://sharkattackfile.net/spreadsheets/pdf_di...          128.0
# 6298  http://sharkattackfile.net/spreadsheets/pdf_di...          126.0
# 6299  http://sharkattackfile.net/spreadsheets/pdf_di...          104.0
# 6300  http://sharkattackfile.net/spreadsheets/pdf_di...           97.0
# 6301  http://sharkattackfile.net/spreadsheets/pdf_di...           44.0
#
#       Sobrevivio
# 0            Yes
# 1            Yes
# 2            Yes
# 3             No
# 4             No
# ...          ...
# 6297         Yes
# 6298         Yes
# 6299          No
# 6300          No
# 6301         Yes
#
# [6302 rows x 21 columns]

# %%
#attack.drop(['original order'], axis = 1 , inplace = True)

# %%
attack.to_csv('clean_attack_shark.csv', index = False)

# %% [markdown]
# #  Fin
